# %%
import pandas as pd

# %%
import pandas as pd

df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
city = ['Berlin','Elrangen', 'Zurich']

# %%
city
# Out:
# ['Berlin', 'Elrangen', 'Zurich']

# %%
df = pd.DataFrame(city)
print(df)
# Out:
#           0
# 0    Berlin
# 1  Elrangen
# 2    Zurich

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(city)
# Out:
# list

# %%
row, col = df.shape

# %%
row
# Out:
# 3

# %%
col
# Out:
# 1

# %%
df.shape
# Out:
# (3, 1)

# %%
df
# Out:
#           0
# 0    Berlin
# 1  Elrangen
# 2    Zurich

# %%
df = pd.DataFrame(city, columns=['city_in_europe'])
df
# Out:
#   city_in_europe
# 0         Berlin
# 1       Elrangen
# 2         Zurich

# %%
df = pd.DataFrame(city, columns=['city_in_europe'], index=['c1','c2','c3'])
df
# Out:
#    city_in_europe
# c1         Berlin
# c2       Elrangen
# c3         Zurich

# %%
city2=['Dortmund','Paris','Potsdam']
df2 = pd.DataFrame(zip(city,city2), columns=['city1','city2'])

# %%
df2.shape
# Out:
# (3, 2)

# %%
df2
# Out:
#       city1     city2
# 0    Berlin  Dortmund
# 1  Elrangen     Paris
# 2    Zurich   Potsdam

# %%
df2.shape
# Out:
# (3, 2)

# %%
city3=[['Bavaria', 'Erlangen'], ['NRW', 'Dortmund']]

# %%
city3
# Out:
# [['Bavaria', 'Erlangen'], ['NRW', 'Dortmund']]

# %%
df4 = pd.DataFrame(city3, columns=["State", "City"])

# %%
df4
# Out:
#      State      City
# 0  Bavaria  Erlangen
# 1      NRW  Dortmund

# %%
city
# Out:
# ['Berlin', 'Elrangen', 'Zurich']

# %%
city2
# Out:
# ['Dortmund', 'Paris', 'Potsdam']

# %%
dic1={
    'city1' : city,
    'city'  : city2
}

# %%
dic1
# Out:
# {'city1': ['Berlin', 'Elrangen', 'Zurich'],
#  'city': ['Dortmund', 'Paris', 'Potsdam']}

# %%
df5 = pd.DataFrame(dic1)

# %%
df5
# Out:
#       city1      city
# 0    Berlin  Dortmund
# 1  Elrangen     Paris
# 2    Zurich   Potsdam

# %%
type(dic1)
# Out:
# dict

# %%
df = pd.read_csv('Screen Time Data.csv')

# %%
df.shape
# Out:
# (28, 12)

# %%
rows,cols=df.shape

# %%
rows
# Out:
# 28

# %%
cols
# Out:
# 12

# %%
print(df.values)
# Out:
# [[0 '04/17/19' 'Wednesday' 187 89 17 41 22 0 0 0 0]
#  [1 '04/18/19' 'Thursday' 123 78 17 8 9 0 0 0 0]
#  [2 '04/19/19' 'Friday' 112 52 40 8 4 0 3 0 0]
#  [3 '04/20/19' 'Saturday' 101 69 9 38 2 0 3 0 0]
#  [4 '04/21/19' 'Sunday' 56 35 2 43 3 0 1 1 0]
#  [5 '04/22/19' 'Monday' 189 68 0 9 3 4 0 0 0]
#  [6 '04/23/19' 'Tuesday' 158 56 18 41 12 15 0 0 0]
#  [7 '04/24/19' 'Wednesday' 135 98 3 33 16 0 0 0 0]
#  [8 '04/25/19' 'Thursday' 52 25 7 3 16 0 0 0 0]
#  [9 '04/26/19' 'Friday' 198 76 8 29 15 0 32 0 0]
#  [10 '04/27/19' 'Saturday' 116 75 10 20 5 0 0 0 0]
#  [11 '04/28/19' 'Sunday' 85 42 22 4 2 0 0 0 0]
#  [12 '04/29/19' 'Monday' 109 46 8 13 9 15 1 0 1]
#  [13 '04/30/19' 'Tuesday' 79 40 2 9 12 0 0 0 1]
#  [14 '05/01/19' 'Wednesday' 127 90 0 10 7 0 0 0 1]
#  [15 '05/02/19' 'Thursday' 170 60 3 2 11 0 0 0 1]
#  [16 '05/03/19' 'Friday' 91 64 2 18 5 1 1 2 1]
#  [17 '05/04/19' 'Saturday' 58 34 4 5 3 0 1 0 1]
#  [18 '05/05/19' 'Sunday' 133 109 5 1 3 0 0 0 1]
# ...

# %%
df.head(3)
# Out:
#    index      Date   Week Day  Total Screen Time   Social Networking  \
# 0      0  04/17/19  Wednesday                 187                 89
# 1      1  04/18/19   Thursday                 123                 78
# 2      2  04/19/19     Friday                 112                 52
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
# 2                     40      8             4                   0
#
#    Entertainment  Creativity  Yoga
# 0              0           0     0
# 1              0           0     0
# 2              3           0     0

# %%
df.Date
# Out:
# 0     04/17/19
# 1     04/18/19
# 2     04/19/19
# 3     04/20/19
# 4     04/21/19
# 5     04/22/19
# 6     04/23/19
# 7     04/24/19
# 8     04/25/19
# 9     04/26/19
# 10    04/27/19
# 11    04/28/19
# 12    04/29/19
# 13    04/30/19
# 14    05/01/19
# 15    05/02/19
# 16    05/03/19
# 17    05/04/19
# 18    05/05/19
# 19    05/06/19
# 20    05/07/19
# 21    05/08/19
# 22    05/09/19
# 23    05/10/19
# 24    05/11/19
# 25    05/12/19
# 26    05/13/19
# 27    05/14/19
# Name: Date, dtype: object

# %%
df[['Social Networking']]
# Out:
#     Social Networking
# 0                  89
# 1                  78
# 2                  52
# 3                  69
# 4                  35
# 5                  68
# 6                  56
# 7                  98
# 8                  25
# 9                  76
# 10                 75
# 11                 42
# 12                 46
# 13                 40
# 14                 90
# 15                 60
# 16                 64
# 17                 34
# 18                109
# 19                 81
# 20                 70
# 21                 53
# 22                 42
# 23                 93
# 24                 49
# 25                 28
# 26                 37
# 27                 41

# %%
df.Date.head(6)
# Out:
# 0    04/17/19
# 1    04/18/19
# 2    04/19/19
# 3    04/20/19
# 4    04/21/19
# 5    04/22/19
# Name: Date, dtype: object

# %%
df.columns = df.columns.str.strip()

# %%
df[['Social Networking']]
# Out:
#     Social Networking
# 0                  89
# 1                  78
# 2                  52
# 3                  69
# 4                  35
# 5                  68
# 6                  56
# 7                  98
# 8                  25
# 9                  76
# 10                 75
# 11                 42
# 12                 46
# 13                 40
# 14                 90
# 15                 60
# 16                 64
# 17                 34
# 18                109
# 19                 81
# 20                 70
# 21                 53
# 22                 42
# 23                 93
# 24                 49
# 25                 28
# 26                 37
# 27                 41

# %%
df.Date.head(6)
# Out:
# 0    04/17/19
# 1    04/18/19
# 2    04/19/19
# 3    04/20/19
# 4    04/21/19
# 5    04/22/19
# Name: Date, dtype: object

# %%
df['Date'].head()
# Out:
# 0    04/17/19
# 1    04/18/19
# 2    04/19/19
# 3    04/20/19
# 4    04/21/19
# Name: Date, dtype: object

# %%
df[['Date','Week Day']].head()
# Out:
#        Date   Week Day
# 0  04/17/19  Wednesday
# 1  04/18/19   Thursday
# 2  04/19/19     Friday
# 3  04/20/19   Saturday
# 4  04/21/19     Sunday

# %%
df.head(6)
# Out:
#    index      Date   Week Day  Total Screen Time  Social Networking  \
# 0      0  04/17/19  Wednesday                187                 89
# 1      1  04/18/19   Thursday                123                 78
# 2      2  04/19/19     Friday                112                 52
# 3      3  04/20/19   Saturday                101                 69
# 4      4  04/21/19     Sunday                 56                 35
# 5      5  04/22/19     Monday                189                 68
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
# 2                     40      8             4                   0
# 3                      9     38             2                   0
# 4                      2     43             3                   0
# 5                      0      9             3                   4
#
# ...

# %%
df['Social Networking']
# Out:
# 0      89
# 1      78
# 2      52
# 3      69
# 4      35
# 5      68
# 6      56
# 7      98
# 8      25
# 9      76
# 10     75
# 11     42
# 12     46
# 13     40
# 14     90
# 15     60
# 16     64
# 17     34
# 18    109
# 19     81
# 20     70
# 21     53
# 22     42
# 23     93
# 24     49
# 25     28
# 26     37
# 27     41
# Name: Social Networking, dtype: int64

# %%
df['Social Networking'].sort_values()
# Out:
# 8      25
# 25     28
# 17     34
# 4      35
# 26     37
# 13     40
# 27     41
# 11     42
# 22     42
# 12     46
# 24     49
# 2      52
# 21     53
# 6      56
# 15     60
# 16     64
# 5      68
# 3      69
# 20     70
# 10     75
# 9      76
# 1      78
# 19     81
# 0      89
# 14     90
# 23     93
# 7      98
# 18    109
# Name: Social Networking, dtype: int64

# %%
df.sort_values('Social Networking', ascending=False)
# Out:
#     index      Date   Week Day  Total Screen Time  Social Networking  \
# 18     18  05/05/19     Sunday                133                109
# 7       7  04/24/19  Wednesday                135                 98
# 23     23  05/10/19     Friday                161                 93
# 14     14  05/01/19  Wednesday                127                 90
# 0       0  04/17/19  Wednesday                187                 89
# 19     19  05/06/19     Monday                144                 81
# 1       1  04/18/19   Thursday                123                 78
# 9       9  04/26/19     Friday                198                 76
# 10     10  04/27/19   Saturday                116                 75
# 20     20  05/07/19    Tuesday                110                 70
# 3       3  04/20/19   Saturday                101                 69
# 5       5  04/22/19     Monday                189                 68
# 16     16  05/03/19     Friday                 91                 64
# ...

# %%
df.sort_values('Social Networking',ascending=True )
# Out:
#     index      Date   Week Day  Total Screen Time  Social Networking  \
# 8       8  04/25/19   Thursday                 52                 25
# 25     25  05/12/19     Sunday                 52                 28
# 17     17  05/04/19   Saturday                 58                 34
# 4       4  04/21/19     Sunday                 56                 35
# 26     26  05/13/19     Monday                 61                 37
# 13     13  04/30/19    Tuesday                 79                 40
# 27     27  05/14/19    Tuesday                 88                 41
# 11     11  04/28/19     Sunday                 85                 42
# 22     22  05/09/19   Thursday                 96                 42
# 12     12  04/29/19     Monday                109                 46
# 24     24  05/11/19   Saturday                 58                 49
# 2       2  04/19/19     Friday                112                 52
# 21     21  05/08/19  Wednesday                122                 53
# ...

# %%
df.describe()
# Out:
#            index  Total Screen Time  Social Networking  Reading and Reference  \
# count  28.000000          28.000000          28.000000              28.000000
# mean   13.500000         113.250000          60.714286               8.714286
# std     8.225975          43.562322          22.853571               9.340700
# min     0.000000          52.000000          25.000000               0.000000
# 25%     6.750000          83.500000          41.750000               2.000000
# 50%    13.500000         111.000000          58.000000               5.000000
# 75%    20.250000         137.250000          76.500000              13.500000
# max    27.000000         198.000000         109.000000              40.000000
#
#            Other  Productivity  Health and Fitness  Entertainment  Creativity  \
# count  28.000000     28.000000           28.000000      28.000000   28.000000
# mean   14.821429      9.071429            1.285714       1.821429    0.214286
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                           index  Total Screen Time  Social Networking  \
# index                  1.000000          -0.344952          -0.218093
# Total Screen Time     -0.344952           1.000000           0.710864
# Social Networking     -0.218093           0.710864           1.000000
# Reading and Reference -0.360073           0.185685           0.004461
# Other                 -0.537331           0.333433           0.234066
# Productivity           0.012553           0.344195           0.124539
# Health and Fitness    -0.178863           0.201360          -0.092968
# Entertainment         -0.113858           0.343897           0.132916
# Creativity             0.221908          -0.409306          -0.214764
# Yoga                   0.857690          -0.258123          -0.110716
#
#                        Reading and Reference     Other  Productivity  \
# index                              -0.360073 -0.537331      0.012553
# ...

# %%
numeric_df = df.select_dtypes(include=['number'])  # Exclude non-numeric columns

# %%
print(numeric_df.head())  # Ensure the numeric data is clean
# Out:
#    index  Total Screen Time  Social Networking  Reading and Reference  Other  \
# 0      0                187                 89                     17     41
# 1      1                123                 78                     17      8
# 2      2                112                 52                     40      8
# 3      3                101                 69                      9     38
# 4      4                 56                 35                      2     43
#
#    Productivity  Health and Fitness  Entertainment  Creativity  Yoga
# 0            22                   0              0           0     0
# 1             9                   0              0           0     0
# 2             4                   0              3           0     0
# 3             2                   0              3           0     0
# 4             3                   0              1           1     0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute correlation
correlation_matrix = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))  # Optional: Adjust the size
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
df.head(5)
# Out:
#    index      Date   Week Day  Total Screen Time  Social Networking  \
# 0      0  04/17/19  Wednesday                187                 89
# 1      1  04/18/19   Thursday                123                 78
# 2      2  04/19/19     Friday                112                 52
# 3      3  04/20/19   Saturday                101                 69
# 4      4  04/21/19     Sunday                 56                 35
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
# 2                     40      8             4                   0
# 3                      9     38             2                   0
# 4                      2     43             3                   0
#
#    Entertainment  Creativity  Yoga
# 0              0           0     0
# 1              0           0     0
# 2              3           0     0
# ...

# %%
df['Social Networking'] >50
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14     True
# 15     True
# 16     True
# 17    False
# 18     True
# 19     True
# 20     True
# 21     True
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# Name: Social Networking, dtype: bool

# %%
df[df['Week Day'] == 'Wednesday']
# Out:
#     index      Date   Week Day  Total Screen Time  Social Networking  \
# 0       0  04/17/19  Wednesday                187                 89
# 7       7  04/24/19  Wednesday                135                 98
# 14     14  05/01/19  Wednesday                127                 90
# 21     21  05/08/19  Wednesday                122                 53
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                      17     41            22                   0
# 7                       3     33            16                   0
# 14                      0     10             7                   0
# 21                     25     26            15                   0
#
#     Entertainment  Creativity  Yoga
# 0               0           0     0
# 7               0           0     0
# 14              0           0     1
# 21              0           0     1

# %%
df[(df['Week Day'] == 'Wednesday') | (df['Week Day'] == 'Sunday')]
# Out:
#     index      Date   Week Day  Total Screen Time  Social Networking  \
# 0       0  04/17/19  Wednesday                187                 89
# 4       4  04/21/19     Sunday                 56                 35
# 7       7  04/24/19  Wednesday                135                 98
# 11     11  04/28/19     Sunday                 85                 42
# 14     14  05/01/19  Wednesday                127                 90
# 18     18  05/05/19     Sunday                133                109
# 21     21  05/08/19  Wednesday                122                 53
# 25     25  05/12/19     Sunday                 52                 28
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                      17     41            22                   0
# 4                       2     43             3                   0
# 7                       3     33            16                   0
# 11                     22      4             2                   0
# ...

# %%
df[(df['Week Day'] == 'Wednesday') | (df['Week Day'] == 'Sunday')]
# Out:
#     index      Date   Week Day  Total Screen Time  Social Networking  \
# 0       0  04/17/19  Wednesday                187                 89
# 4       4  04/21/19     Sunday                 56                 35
# 7       7  04/24/19  Wednesday                135                 98
# 11     11  04/28/19     Sunday                 85                 42
# 14     14  05/01/19  Wednesday                127                 90
# 18     18  05/05/19     Sunday                133                109
# 21     21  05/08/19  Wednesday                122                 53
# 25     25  05/12/19     Sunday                 52                 28
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                      17     41            22                   0
# 4                       2     43             3                   0
# 7                       3     33            16                   0
# 11                     22      4             2                   0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(numeric_df)  # Replace numeric_df with your DataFrame
plt.show()

# %%
sns.boxplot(x='Week Day', y='Total Screen Time', data=df)  # Replace 'Week Day' and 'Total Screen Time' with your columns
plt.show()

# %%
sns.countplot(x='Week Day', data=df)  # Replace 'Week Day' with your column
plt.show()

# %%
sns.histplot(df['Total Screen Time'], kde=True)  # Replace 'Total Screen Time' with your column
plt.show()

# %%
g = sns.FacetGrid(df, col='Week Day', row='Week Day')  # You can replace the row/col parameters as needed
g.map(sns.scatterplot, 'Total Screen Time', 'Social Networking')
plt.show()

# %%
specific_cols = df[['Total Screen Time', 'Social Networking', 'Reading and Reference']]  # Select specific columns
sns.heatmap(specific_cols.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
sns.regplot(x='Total Screen Time', y='Social Networking', data=df)  # Replace with your columns
plt.show()

# %%
sns.stripplot(x='Week Day', y='Total Screen Time', data=df, jitter=True)  # Replace columns as needed
plt.show()

# %%
sns.barplot(x='Week Day', y='Total Screen Time', data=df)
plt.title('Screen Time by Week Day')
plt.xlabel('Day of the Week')
plt.ylabel('Total Screen Time')
plt.show()

# %%
# # Define the data
# cars = {'Brand': ["Honda", "Toyota"], 'Price': [22000, 25000]}

# # Create the DataFrame
# df = pd.DataFrame(cars)

# # Print the DataFrame
# print(df)
